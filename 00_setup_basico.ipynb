# %% [markdown]
# # Setup básico (una sola vez)
# Este notebook contiene el *setup* que se reutiliza en los demás ejemplos.
#
# **Objetivo:** asegurar que tenemos `numpy` y `matplotlib` listos para simular y graficar.

# %%
# ============================================================
# SETUP BÁSICO PARA TODOS LOS NOTEBOOKS
# ============================================================

import numpy as np                      # Para números, arreglos y simulación
import matplotlib.pyplot as plt         # Para visualizar resultados

# Esto hace que los gráficos se vean dentro del notebook
# %matplotlib inline
